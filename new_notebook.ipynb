# %%
import test_python as lib

lib.add(1,2)
# Out:
# Adding numbers 1 and 2
# 3

# %%
import new_dir.lib1 as lib1

lib1.func('a')
# Out:
# printing input: a
# 'foo'

# %%
import new_dir

dir(new_dir)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'lib1']

# %%
import json
with open('Repo/new_dir/newjson.json', 'r') as f:
    dict = json.load(f)

# %%
pd.DataFrame(dict).to_csv('test.csv')

# %%
df = pd.read_csv('test.csv')
df
# Out:
#    Unnamed: 0  key1  key2
# 0           0  val1  val2
# 1           1  val3  val4

# %%
from os import listdir as ls
ls()
# Out:
# ['testfile.ipynb',
#  'new_text.txt',
#  'Data',
#  'test.csv',
#  'Repo',
#  'new_text2.txt',
#  'test.py']

# %%
# some more changes
